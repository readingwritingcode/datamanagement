# %%
import pandas as pd 
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('./spotify.csv', index_col='Date',parse_dates=True)

# %%
plt.figure(figsize=(16,8))

plt.title('Did the best bro')

sns.lineplot(data=data)
# Out:
# <AxesSubplot:title={'center':'Did the best bro'}, xlabel='Date'>

# %%
# plot a subset of colums
list(data.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %%
plt.figure(figsize=(16,8))

plt.title('did the best!')

sns.lineplot(data=data['Shape of You'], label='shape of you')

sns.lineplot(data=data['HUMBLE.'],label='HUMBLE.')

plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
# see later: https://stackoverflow.com/questions/61162537/how-do-i-change-the-axes-units-in-a-figure

# %%
f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale()
